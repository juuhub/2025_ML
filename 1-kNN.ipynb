# %% [markdown]
# k-최근접 이웃 : 도미, 빙어 판별기

# %%
# 도미 길이, 무게 data
bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

# %%
# 길이, 무게 data로 산점도 생성
import matplotlib.pyplot as plt
plt.scatter(bream_length, bream_weight)
plt.xlabel('Length') # x축 title
plt.ylabel('Weight') # y축 title
plt.show() # 산점도 출력

# %%
# 빙어 길이, 무게 data
smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# 도미, 빙어 data에 대한 두 개의 산점도를 그래프에 표현
plt.scatter(bream_length, bream_weight)
plt.scatter(smelt_length, smelt_weight)
plt.xlabel('Length')
plt.ylabel('Weight')
plt.show()

# %%
length = bream_length + smelt_length
weight = bream_weight + smelt_weight

# 두 데이터를 합치고 fish_data 리스트 요소로 넣어서 이중 리스트 생성
# zip 함수로 length와 weight 리스트에서 원소를 하나씩 꺼내서 l과 w에 할당
fish_data = [[l,w] for l,w in zip(length, weight)]

# 정답 리스트 생성 (도미:1, 빙어:0) -> 지도학습
fish_target = [1]*35 + [0]*14

# %%
from sklearn.neighbors import KNeighborsClassifier # k-최근접 이웃 알고리즘 구현 클래스 import
kn = KNeighborsClassifier() # 객체(모델) 생성
kn.fit(fish_data, fish_target) # 모델 학습
kn.score(fish_data, fish_target) # 모델 평가(0~1 값)
# Out:
# 1.0

# %%
# fit에 전달한 데이터 저장하고 있다가 새로운 데이터 오면 가장 가까운 데이터들을 참고하여 구분(default: 5개)
kn.predict([[3,50]])
kn49 = KNeighborsClassifier(n_neighbors=49) # 참고 data 수를 49개로 설정
kn49.fit(fish_data, fish_target)
kn49.score(fish_data, fish_target) # 49개 data를 모두 도미로 판정하기 때문 (35/49)
# Out:
# 0.7142857142857143

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/2025_ML
# Out:
# /content/drive/MyDrive/2025_ML

# %%
# !git config --global user.email kkimjjhh135@gmail.com
# !git config --global user.name juuhub
